# %% [markdown]
# Connected to Python 3.12.7

# %%
import pandas as pd


data= pd.read_csv('./US_Accidents_March23.csv')

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7728394 entries, 0 to 7728393
# Data columns (total 46 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   ID                     object
#  1   Source                 object
#  2   Severity               int64
#  3   Start_Time             object
#  4   End_Time               object
#  5   Start_Lat              float64
#  6   Start_Lng              float64
#  7   End_Lat                float64
#  8   End_Lng                float64
#  9   Distance(mi)           float64
#  10  Description            object
#  11  Street                 object
#  12  City                   object
#  13  County                 object
#  14  State                  object
#  15  Zipcode                object
#  16  Country                object
#  17  Timezone               object
#  18  Airport_Code           object
#  19  Weather_Timestamp      object
#  20  Temperature(F)         float64
# ...

# %%
data.describe()
# Out:
#            Severity     Start_Lat     Start_Lng       End_Lat       End_Lng  \
# count  7.728394e+06  7.728394e+06  7.728394e+06  4.325632e+06  4.325632e+06
# mean   2.212384e+00  3.620119e+01 -9.470255e+01  3.626183e+01 -9.572557e+01
# std    4.875313e-01  5.076079e+00  1.739176e+01  5.272905e+00  1.810793e+01
# min    1.000000e+00  2.455480e+01 -1.246238e+02  2.456601e+01 -1.245457e+02
# 25%    2.000000e+00  3.339963e+01 -1.172194e+02  3.346207e+01 -1.177543e+02
# 50%    2.000000e+00  3.582397e+01 -8.776662e+01  3.618349e+01 -8.802789e+01
# 75%    2.000000e+00  4.008496e+01 -8.035368e+01  4.017892e+01 -8.024709e+01
# max    4.000000e+00  4.900220e+01 -6.711317e+01  4.907500e+01 -6.710924e+01
#
#        Distance(mi)  Temperature(F)  Wind_Chill(F)   Humidity(%)  \
# count  7.728394e+06    7.564541e+06   5.729375e+06  7.554250e+06
# mean   5.618423e-01    6.166329e+01   5.825105e+01  6.483104e+01
# std    1.776811e+00    1.901365e+01   2.238983e+01  2.282097e+01
# ...

# %%
data.isna().sum()
# Out:
# ID                             0
# Source                         0
# Severity                       0
# Start_Time                     0
# End_Time                       0
# Start_Lat                      0
# Start_Lng                      0
# End_Lat                  3402762
# End_Lng                  3402762
# Distance(mi)                   0
# Description                    5
# Street                     10869
# City                         253
# County                         0
# State                          0
# Zipcode                     1915
# Country                        0
# Timezone                    7808
# Airport_Code               22635
# Weather_Timestamp         120228
# Temperature(F)            163853
# Wind_Chill(F)            1999019
# Humidity(%)               174144
# Pressure(in)              140679
# Visibility(mi)            177098
# Wind_Direction            175206
# Wind_Speed(mph)           571233
# Precipitation(in)        2203586
# ...

# %%
data= data.dropna()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3554549 entries, 3402762 to 7728393
# Data columns (total 46 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   ID                     object
#  1   Source                 object
#  2   Severity               int64
#  3   Start_Time             object
#  4   End_Time               object
#  5   Start_Lat              float64
#  6   Start_Lng              float64
#  7   End_Lat                float64
#  8   End_Lng                float64
#  9   Distance(mi)           float64
#  10  Description            object
#  11  Street                 object
#  12  City                   object
#  13  County                 object
#  14  State                  object
#  15  Zipcode                object
#  16  Country                object
#  17  Timezone               object
#  18  Airport_Code           object
#  19  Weather_Timestamp      object
#  20  Temperature(F)         float64
# ...

# %%
data.isna().sum()
# Out:
# ID                       0
# Source                   0
# Severity                 0
# Start_Time               0
# End_Time                 0
# Start_Lat                0
# Start_Lng                0
# End_Lat                  0
# End_Lng                  0
# Distance(mi)             0
# Description              0
# Street                   0
# City                     0
# County                   0
# State                    0
# Zipcode                  0
# Country                  0
# Timezone                 0
# Airport_Code             0
# Weather_Timestamp        0
# Temperature(F)           0
# Wind_Chill(F)            0
# Humidity(%)              0
# Pressure(in)             0
# Visibility(mi)           0
# Wind_Direction           0
# Wind_Speed(mph)          0
# Precipitation(in)        0
# Weather_Condition        0
# Amenity                  0
# Bump                     0
# Crossing                 0
# Give_Way                 0
# Junction                 0
# ...

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.shape
# Out:
# (3554549, 46)

# %%
data.describe()
# Out:
#            Severity     Start_Lat     Start_Lng       End_Lat       End_Lng  \
# count  3.554549e+06  3.554549e+06  3.554549e+06  3.554549e+06  3.554549e+06
# mean   2.075250e+00  3.612065e+01 -9.521825e+01  3.612085e+01 -9.521794e+01
# std    3.837690e-01  5.352725e+00  1.801263e+01  5.352925e+00  1.801231e+01
# min    1.000000e+00  2.456603e+01 -1.245481e+02  2.456601e+01 -1.245457e+02
# 25%    2.000000e+00  3.318008e+01 -1.175560e+02  3.317923e+01 -1.175546e+02
# 50%    2.000000e+00  3.604521e+01 -8.731360e+01  3.604546e+01 -8.731348e+01
# 75%    2.000000e+00  4.013914e+01 -8.021014e+01  4.013945e+01 -8.020993e+01
# max    4.000000e+00  4.900058e+01 -6.748413e+01  4.907500e+01 -6.748413e+01
#
#        Distance(mi)  Temperature(F)  Wind_Chill(F)   Humidity(%)  \
# count  3.554549e+06    3.554549e+06   3.554549e+06  3.554549e+06
# mean   8.477587e-01    6.107390e+01   5.974164e+01  6.377543e+01
# std    1.823782e+00    1.939819e+01   2.168704e+01  2.292699e+01
# ...

# %%
data= pd.read_csv('./US_Accidents_March23.csv')

# %%
data.loc[data['Street'].isna(),['Street', 'Description']]
# Out:
#         Street                                        Description
# 512237     NaN  Right lane blocked due to multi-vehicle crash ...
# 512280     NaN           Crash on I-4 Westbound at Exit 55 US-27.
# 512453     NaN  Left hand shoulder blocked due to crash on I-7...
# 512787     NaN  Crash on I-87 Southbound at Exit 3 I-440 Cliff...
# 512931     NaN            Crash on US-1 at SC-34 Bishopville Hwy.
# ...        ...                                                ...
# 6928152    NaN  Incident on I-95 SB near NW 79TH ST Drive with...
# 7063579    NaN                           At Pedley Rd - Accident.
# 7588503    NaN           At I-695 - Accident. Right lane blocked.
# 7601453    NaN               At I-526/Mark Clark Expy - Accident.
# 7633451    NaN  Closed at CA-99/Stockton Blvd - Road closed du...
#
# [10869 rows x 2 columns]

# %%
data.loc[data['Street'].isna(),['Street', 'Description']].head(5)
# Out:
#        Street                                        Description
# 512237    NaN  Right lane blocked due to multi-vehicle crash ...
# 512280    NaN           Crash on I-4 Westbound at Exit 55 US-27.
# 512453    NaN  Left hand shoulder blocked due to crash on I-7...
# 512787    NaN  Crash on I-87 Southbound at Exit 3 I-440 Cliff...
# 512931    NaN            Crash on US-1 at SC-34 Bishopville Hwy.

# %%
data.loc[data['Street'].isna(), 'Description']
# Out:
# 512237     Right lane blocked due to multi-vehicle crash ...
# 512280              Crash on I-4 Westbound at Exit 55 US-27.
# 512453     Left hand shoulder blocked due to crash on I-7...
# 512787     Crash on I-87 Southbound at Exit 3 I-440 Cliff...
# 512931               Crash on US-1 at SC-34 Bishopville Hwy.
#                                  ...
# 6928152    Incident on I-95 SB near NW 79TH ST Drive with...
# 7063579                             At Pedley Rd - Accident.
# 7588503             At I-695 - Accident. Right lane blocked.
# 7601453                 At I-526/Mark Clark Expy - Accident.
# 7633451    Closed at CA-99/Stockton Blvd - Road closed du...
# Name: Description, Length: 10869, dtype: object

# %%
missing_street_data = data.loc[data['Street'].isna(), 'Description']

for description in missing_street_data.head(10):
    print(description)
# Out:
# Right lane blocked due to multi-vehicle crash on I-95 Southbound before Exit 22 FL-848 Stirling Rd.
# Crash on I-4 Westbound at Exit 55 US-27.
# Left hand shoulder blocked due to crash on I-77 Southbound at Exit 151 Wallings Rd.
# Crash on I-87 Southbound at Exit 3 I-440 Cliff Benson Beltline Exit 14.
# Crash on US-1 at SC-34 Bishopville Hwy.
# Crash on I-4 Westbound at Exit 55 US-27.
# Crash on exit ramp from AZ-202-LOOP Southbound at Exit 57 to S 32nd St Southbound.
# Entry ramp to Eisenhower Expy Westbound at Exits 30A 30B 31 31A 31B from I-294 Northbound lane blocked due to crash.
# Right lane blocked due to crash on FL-821 Florida's Tpke Northbound at Exit 34 106th St.
# Crash on Hazel Ave Northbound at Tributary Point Dr.

# %%
data.isna().sum()
# Out:
# ID                             0
# Source                         0
# Severity                       0
# Start_Time                     0
# End_Time                       0
# Start_Lat                      0
# Start_Lng                      0
# End_Lat                  3402762
# End_Lng                  3402762
# Distance(mi)                   0
# Description                    5
# Street                     10869
# City                         253
# County                         0
# State                          0
# Zipcode                     1915
# Country                        0
# Timezone                    7808
# Airport_Code               22635
# Weather_Timestamp         120228
# Temperature(F)            163853
# Wind_Chill(F)            1999019
# Humidity(%)               174144
# Pressure(in)              140679
# Visibility(mi)            177098
# Wind_Direction            175206
# Wind_Speed(mph)           571233
# Precipitation(in)        2203586
# ...

# %%
data= data.dropna()

# %%
data.describe()
# Out:
#            Severity     Start_Lat     Start_Lng       End_Lat       End_Lng  \
# count  3.554549e+06  3.554549e+06  3.554549e+06  3.554549e+06  3.554549e+06
# mean   2.075250e+00  3.612065e+01 -9.521825e+01  3.612085e+01 -9.521794e+01
# std    3.837690e-01  5.352725e+00  1.801263e+01  5.352925e+00  1.801231e+01
# min    1.000000e+00  2.456603e+01 -1.245481e+02  2.456601e+01 -1.245457e+02
# 25%    2.000000e+00  3.318008e+01 -1.175560e+02  3.317923e+01 -1.175546e+02
# 50%    2.000000e+00  3.604521e+01 -8.731360e+01  3.604546e+01 -8.731348e+01
# 75%    2.000000e+00  4.013914e+01 -8.021014e+01  4.013945e+01 -8.020993e+01
# max    4.000000e+00  4.900058e+01 -6.748413e+01  4.907500e+01 -6.748413e+01
#
#        Distance(mi)  Temperature(F)  Wind_Chill(F)   Humidity(%)  \
# count  3.554549e+06    3.554549e+06   3.554549e+06  3.554549e+06
# mean   8.477587e-01    6.107390e+01   5.974164e+01  6.377543e+01
# std    1.823782e+00    1.939819e+01   2.168704e+01  2.292699e+01
# ...

# %%
data[data['Distance(mi)'] == 0].head(5)
# Out:
#                 ID   Source  Severity           Start_Time  \
# 3402822  A-3412705  Source1         3  2016-02-10 09:08:29
# 3402872  A-3412755  Source1         2  2016-02-11 11:42:07
# 3402876  A-3412759  Source1         2  2016-02-11 13:25:43
# 3402877  A-3412760  Source1         2  2016-02-11 13:30:58
# 3402883  A-3412766  Source1         2  2016-02-11 16:56:28
#
#                     End_Time  Start_Lat  Start_Lng    End_Lat    End_Lng  \
# 3402822  2016-02-10 15:08:29  38.271910 -85.808380  38.271910 -85.808380
# 3402872  2016-02-11 17:42:07  41.039988 -81.565332  41.039994 -81.565332
# 3402876  2016-02-11 19:25:43  41.256660 -81.631570  41.256660 -81.631570
# 3402877  2016-02-11 19:30:58  40.589190 -80.098850  40.589190 -80.098850
# 3402883  2016-02-11 22:56:28  40.589190 -80.098850  40.589190 -80.098850
#
#          Distance(mi)  ... Roundabout Station   Stop Traffic_Calming  \
# 3402822           0.0  ...      False   False  False           False
# ...

# %%
data.loc[data['Distance(mi)'] == 0,['Street','Severity']].head(5)
# Out:
#                          Street  Severity
# 3402822  Henry Watterson Expy W         3
# 3402872                  I-76 W         2
# 3402876                 OH-21 N         2
# 3402877            Rochester Rd         2
# 3402883            Rochester Rd         2

# %%
data.loc[data['Distance(mi)'] == 0,['Street','Severity','Description']].head(5)
# Out:
#                          Street  Severity  \
# 3402822  Henry Watterson Expy W         3
# 3402872                  I-76 W         2
# 3402876                 OH-21 N         2
# 3402877            Rochester Rd         2
# 3402883            Rochester Rd         2
#
#                                           Description
# 3402822                 At Bank St/Exit 1 - Accident.
# 3402872                        At Exit 18 - Accident.
# 3402876  At OH-21/Brecksville Rd/Exit 145 - Accident.
# 3402877                  At I-279/Exit 72 - Accident.
# 3402883                  At I-279/Exit 72 - Accident.

# %%
data= data.drop(['ID', 'Source'], axis=1)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3554549 entries, 3402762 to 7728393
# Data columns (total 44 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   Severity               int64
#  1   Start_Time             object
#  2   End_Time               object
#  3   Start_Lat              float64
#  4   Start_Lng              float64
#  5   End_Lat                float64
#  6   End_Lng                float64
#  7   Distance(mi)           float64
#  8   Description            object
#  9   Street                 object
#  10  City                   object
#  11  County                 object
#  12  State                  object
#  13  Zipcode                object
#  14  Country                object
#  15  Timezone               object
#  16  Airport_Code           object
#  17  Weather_Timestamp      object
#  18  Temperature(F)         float64
#  19  Wind_Chill(F)          float64
#  20  Humidity(%)            float64
# ...

# %%
data= data.drop(['Start_Lat', 'Start_Lng','End_Lat', 'End_Lng'], axis=1)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3554549 entries, 3402762 to 7728393
# Data columns (total 40 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   Severity               int64
#  1   Start_Time             object
#  2   End_Time               object
#  3   Distance(mi)           float64
#  4   Description            object
#  5   Street                 object
#  6   City                   object
#  7   County                 object
#  8   State                  object
#  9   Zipcode                object
#  10  Country                object
#  11  Timezone               object
#  12  Airport_Code           object
#  13  Weather_Timestamp      object
#  14  Temperature(F)         float64
#  15  Wind_Chill(F)          float64
#  16  Humidity(%)            float64
#  17  Pressure(in)           float64
#  18  Visibility(mi)         float64
#  19  Wind_Direction         object
#  20  Wind_Speed(mph)        float64
# ...

# %%
data= data.drop(['Description'], axis=1)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3554549 entries, 3402762 to 7728393
# Data columns (total 39 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   Severity               int64
#  1   Start_Time             object
#  2   End_Time               object
#  3   Distance(mi)           float64
#  4   Street                 object
#  5   City                   object
#  6   County                 object
#  7   State                  object
#  8   Zipcode                object
#  9   Country                object
#  10  Timezone               object
#  11  Airport_Code           object
#  12  Weather_Timestamp      object
#  13  Temperature(F)         float64
#  14  Wind_Chill(F)          float64
#  15  Humidity(%)            float64
#  16  Pressure(in)           float64
#  17  Visibility(mi)         float64
#  18  Wind_Direction         object
#  19  Wind_Speed(mph)        float64
#  20  Precipitation(in)      float64
# ...

# %%
data['Start_Time']= pd.to_datetime(data['Start_Time'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 data['Start_Time']= pd.to_datetime(data['Start_Time'])
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\tools\datetimes.py:1112, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1110         result = arg.map(cache_array)
#    1111     else:
# -> 1112         values = convert_listlike(arg._values, format)
#    1113         result = arg._constructor(values, index=arg.index, name=arg.name)
#    1114 elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# ...

# %%
data.iloc[9262]
# Out:
# Severity                                             2
# Start_Time               2017-07-24 07:15:46.000000000
# End_Time                 2017-07-24 13:15:46.000000000
# Distance(mi)                                      0.48
# Street                                         CA-14 S
# City                                           Newhall
# County                                     Los Angeles
# State                                               CA
# Zipcode                                          91321
# Country                                             US
# Timezone                                    US/Pacific
# Airport_Code                                      K3A6
# Weather_Timestamp                  2017-07-24 06:51:00
# Temperature(F)                                    67.0
# Wind_Chill(F)                                     67.0
# Humidity(%)                                       87.0
# Pressure(in)                                     29.06
# ...

# %%
data.iloc[9262]['Start_Time']
# Out:
# '2017-07-24 07:15:46.000000000'

# %%
(data.iloc[9262]['Start_Time'])[:data.iloc[9262]['Start_Time'].find('.')]
# Out:
# '2017-07-24 07:15:46'
